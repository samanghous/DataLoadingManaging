# %%
import numpy as np
import pandas as pd

# %%
#sam_data=pd.read_csv('covid-data.csv','covid-data',index_col=None,na_values=['NA'])
#file1='covid-data.csv'
sam_data=pd.read_csv('covid-data.csv')

# %%
sam_data.head(7)
# Out:
#           FRN     USA  UK  IRN  AVG_PRCUS  SPN  GER  PRC  DATE     ITL
# 0  2020-01-22   548.0   1    0          0    0    0    0     0   274.5
# 1  2020-01-23   643.0   1    0          0    0    0    0     0   322.0
# 2  2020-01-24   920.0   2    0          0    2    0    0     0   461.0
# 3  2020-01-25  1406.0   2    0          0    3    0    0     0   704.0
# 4  2020-01-26  2075.0   5    0          0    3    0    0     0  1040.0
# 5  2020-01-27  2877.0   5    0          0    3    1    0     0  1441.0
# 6  2020-01-28  5509.0   5    0          0    4    4    0     0  2757.0

# %%
sam_data.describe()
# Out:
#               China             US  United_Kingdom         Italy  \
# count     66.000000      66.000000       66.000000     66.000000
# mean   58457.530303    7191.287879     1222.954545  12324.196970
# std    30066.059368   19826.002110     2941.878910  22766.937382
# min      548.000000       1.000000        0.000000      0.000000
# 25%    34786.000000      11.000000        3.000000      3.000000
# 50%    77131.500000      33.000000       11.000000    192.000000
# 75%    80912.500000    1200.500000      440.250000  11883.750000
# max    81897.000000  101657.000000    14745.000000  86498.000000
#
#              France       Germany         Spain          Iran
# count     66.000000     66.000000     66.000000     66.000000
# mean    3545.484848   5004.166667   6143.530303   5571.924242
# std     7592.922077  11303.089084  14266.547760   8820.095263
# min        0.000000      0.000000      0.000000      0.000000
# 25%        7.250000     13.000000      1.000000      0.000000
# ...

# %%
 sam_data
# Out:
#            FRN      USA      UK    IRN  AVG_PRCUS    SPN    GER    PRC   DATE  \
# 0   2020-01-22    548.0       1      0          0      0      0      0      0
# 1   2020-01-23    643.0       1      0          0      0      0      0      0
# 2   2020-01-24    920.0       2      0          0      2      0      0      0
# 3   2020-01-25   1406.0       2      0          0      3      0      0      0
# 4   2020-01-26   2075.0       5      0          0      3      0      0      0
# ..         ...      ...     ...    ...        ...    ...    ...    ...    ...
# 61  2020-03-23  81498.0   43847   6726      63927  20123  29056  35136  23049
# 62  2020-03-24  81591.0   53740   8164      69176  22622  32986  39885  24811
# 63  2020-03-25  81661.0   65778   9640      74386  25600  37323  49515  27017
# 64  2020-03-26  81782.0   83836  11812      80589  29551  43938  57786  29406
# 65  2020-03-27  81897.0  101657  14745      86498  33402  50871  65719  32332
#
#         ITL
# 0     274.5
# ...

# %%
print(sam_data.tail(10))
# Out:
#           Date  China      US  United_Kingdom  Italy  France  Germany  Spain  \
# 56  2020-03-18  81102    7783            2642  35713    9124    12327  13910
# 57  2020-03-19  81156   13677            2716  41035   10970    15320  17963
# 58  2020-03-20  81250   19100            4014  47021   12758    19848  20410
# 59  2020-03-21  81305   25489            5067  53578   14463    22213  25374
# 60  2020-03-22  81435   33276            5745  59138   16243    24873  28768
# 61  2020-03-23  81498   43847            6726  63927   20123    29056  35136
# 62  2020-03-24  81591   53740            8164  69176   22622    32986  39885
# 63  2020-03-25  81661   65778            9640  74386   25600    37323  49515
# 64  2020-03-26  81782   83836           11812  80589   29551    43938  57786
# 65  2020-03-27  81897  101657           14745  86498   33402    50871  65719
#
#      Iran
# 56  17361
# 57  18407
# 58  19644
# 59  20610
# 60  21638
# 61  23049
# 62  24811
# 63  27017
# 64  29406
# ...

# %%
sam_data.dtypes
# Out:
# Date              object
# China              int64
# US                 int64
# United_Kingdom     int64
# Italy              int64
# France             int64
# Germany            int64
# Spain              int64
# Iran               int64
# dtype: object

# %%
sam_data.index
# Out:
# RangeIndex(start=0, stop=66, step=1)

# %%
sam_data.columns
# Out:
# Index(['Date', 'China', 'US', 'United_Kingdom', 'Italy', 'France', 'Germany',
#        'Spain', 'Iran'],
#       dtype='object')

# %%
sam_data.values
# Out:
# array([['2020-01-22', 548, 1, 0, 0, 0, 0, 0, 0],
#        ['2020-01-23', 643, 1, 0, 0, 0, 0, 0, 0],
#        ['2020-01-24', 920, 2, 0, 0, 2, 0, 0, 0],
#        ['2020-01-25', 1406, 2, 0, 0, 3, 0, 0, 0],
#        ['2020-01-26', 2075, 5, 0, 0, 3, 0, 0, 0],
#        ['2020-01-27', 2877, 5, 0, 0, 3, 1, 0, 0],
#        ['2020-01-28', 5509, 5, 0, 0, 4, 4, 0, 0],
#        ['2020-01-29', 6087, 5, 0, 0, 5, 4, 0, 0],
#        ['2020-01-30', 8141, 5, 0, 0, 5, 4, 0, 0],
#        ['2020-01-31', 9802, 7, 2, 2, 5, 5, 0, 0],
#        ['2020-02-01', 11891, 8, 2, 2, 6, 8, 1, 0],
#        ['2020-02-02', 16630, 8, 2, 2, 6, 10, 1, 0],
#        ['2020-02-03', 19716, 11, 2, 2, 6, 12, 1, 0],
#        ['2020-02-04', 23707, 11, 2, 2, 6, 12, 1, 0],
#        ['2020-02-05', 27440, 11, 2, 2, 6, 12, 1, 0],
#        ['2020-02-06', 30587, 11, 2, 2, 6, 12, 1, 0],
#        ['2020-02-07', 34110, 11, 3, 3, 6, 13, 1, 0],
#        ['2020-02-08', 36814, 11, 3, 3, 11, 13, 1, 0],
# ...

# %%
def func1(sam1): sam1*'*'

# %%
sam_data.sort_values('France',ascending=True)
# Out:
#           Date  China      US  United_Kingdom  Italy  France  Germany  Spain  \
# 0   2020-01-22    548       1               0      0       0        0      0
# 1   2020-01-23    643       1               0      0       0        0      0
# 2   2020-01-24    920       2               0      0       2        0      0
# 3   2020-01-25   1406       2               0      0       3        0      0
# 4   2020-01-26   2075       5               0      0       3        0      0
# ..         ...    ...     ...             ...    ...     ...      ...    ...
# 61  2020-03-23  81498   43847            6726  63927   20123    29056  35136
# 62  2020-03-24  81591   53740            8164  69176   22622    32986  39885
# 63  2020-03-25  81661   65778            9640  74386   25600    37323  49515
# 64  2020-03-26  81782   83836           11812  80589   29551    43938  57786
# 65  2020-03-27  81897  101657           14745  86498   33402    50871  65719
#
#      Iran
# 0       0
# 1       0
# ...

# %%
sam_data.China
# Out:
# 0       548
# 1       643
# 2       920
# 3      1406
# 4      2075
#       ...
# 61    81498
# 62    81591
# 63    81661
# 64    81782
# 65    81897
# Name: China, Length: 66, dtype: int64

# %%
sam_data['China']
# Out:
# 0       548
# 1       643
# 2       920
# 3      1406
# 4      2075
#       ...
# 61    81498
# 62    81591
# 63    81661
# 64    81782
# 65    81897
# Name: China, Length: 66, dtype: int64

# %%
sam_data[0:2]
# Out:
#          Date  China  US  United_Kingdom  Italy  France  Germany  Spain  Iran
# 0  2020-01-22    548   1               0      0       0        0      0     0
# 1  2020-01-23    643   1               0      0       0        0      0     0

# %%
sam_data[['China','US']]
# Out:
#     China      US
# 0     548       1
# 1     643       1
# 2     920       2
# 3    1406       2
# 4    2075       5
# ..    ...     ...
# 61  81498   43847
# 62  81591   53740
# 63  81661   65778
# 64  81782   83836
# 65  81897  101657
#
# [66 rows x 2 columns]

# %%
sam_data.loc[2:5,['US','China']]
# Out:
#    US  China
# 2   2    920
# 3   2   1406
# 4   5   2075
# 5   5   2877

# %%
sam_data.loc[9,['US','China']]
# Out:
# US          7
# China    9802
# Name: 9, dtype: object

# %%
sam_data.iloc[0:5,[0,4,1]]
# Out:
#          Date  Italy  China
# 0  2020-01-22      0    548
# 1  2020-01-23      0    643
# 2  2020-01-24      0    920
# 3  2020-01-25      0   1406
# 4  2020-01-26      0   2075

# %%
sam_data[sam_data.China<80000]
# Out:
#           Date  China  US  United_Kingdom  Italy  France  Germany  Spain  Iran
# 0   2020-01-22    548   1               0      0       0        0      0     0
# 1   2020-01-23    643   1               0      0       0        0      0     0
# 2   2020-01-24    920   2               0      0       2        0      0     0
# 3   2020-01-25   1406   2               0      0       3        0      0     0
# 4   2020-01-26   2075   5               0      0       3        0      0     0
# 5   2020-01-27   2877   5               0      0       3        1      0     0
# 6   2020-01-28   5509   5               0      0       4        4      0     0
# 7   2020-01-29   6087   5               0      0       5        4      0     0
# 8   2020-01-30   8141   5               0      0       5        4      0     0
# 9   2020-01-31   9802   7               2      2       5        5      0     0
# 10  2020-02-01  11891   8               2      2       6        8      1     0
# ...

# %%
sam_data[sam_data['Germany'].isin[5,8]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Germany'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-791f23856cdd> in <module>
# ...

# %%
sam_data.array(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-6cc0f6f240f0> in <module>
# ----> 1 sam_data.array(3)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'array'

# %%
#change some data
sam_data.loc[9,['China']]=10000000

# %%
sam_data.iloc[9:10]
# Out:
#          Date     China  US  United_Kingdom  Italy  France  Germany  Spain  \
# 9  2020-01-31  10000000   7               2      2       5        5      0
#
#    Iran
# 9     0

# %%
sam_data.loc[9,['China']]=np.nan

# %%
sam_data.iloc[9:13]
# Out:
#           Date    China  US  United_Kingdom  Italy  France  Germany  Spain  \
# 9   2020-01-31      NaN   7               2      2       5        5      0
# 10  2020-02-01  11891.0   8               2      2       6        8      1
# 11  2020-02-02  16630.0   8               2      2       6       10      1
# 12  2020-02-03  19716.0  11               2      2       6       12      1
#
#     Iran
# 9      0
# 10     0
# 11     0
# 12     0

# %%
sam_data.loc[:,'China']=sam_data.array([10000]*len(sam_data))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-3c5964e2640f> in <module>
# ----> 1 sam_data.loc[:,'China']=sam_data.array([10000]*len(sam_data))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'array'

# %%
sam_data['sam_eg']=(sam_data.China+sam_data.US)/2

# %%
sam_data.iloc[:]
# Out:
#           Date    China      US  United_Kingdom  Italy  France  Germany  \
# 0   2020-01-22    548.0       1               0      0       0        0
# 1   2020-01-23    643.0       1               0      0       0        0
# 2   2020-01-24    920.0       2               0      0       2        0
# 3   2020-01-25   1406.0       2               0      0       3        0
# 4   2020-01-26   2075.0       5               0      0       3        0
# ..         ...      ...     ...             ...    ...     ...      ...
# 61  2020-03-23  81498.0   43847            6726  63927   20123    29056
# 62  2020-03-24  81591.0   53740            8164  69176   22622    32986
# 63  2020-03-25  81661.0   65778            9640  74386   25600    37323
# 64  2020-03-26  81782.0   83836           11812  80589   29551    43938
# 65  2020-03-27  81897.0  101657           14745  86498   33402    50871
#
#     Spain   Iran   sam_eg
# 0       0      0    274.5
# 1       0      0    322.0
# ...

# %%
sam_data=sam_data.rename(columns={'China':'PRC','US':'USA'})

# %%
sam_data.head()
# Out:
#          Date     PRC  USA  United_Kingdom  Italy  France  Germany  Spain  \
# 0  2020-01-22   548.0    1               0      0       0        0      0
# 1  2020-01-23   643.0    1               0      0       0        0      0
# 2  2020-01-24   920.0    2               0      0       2        0      0
# 3  2020-01-25  1406.0    2               0      0       3        0      0
# 4  2020-01-26  2075.0    5               0      0       3        0      0
#
#    Iran  sam_eg
# 0     0   274.5
# 1     0   322.0
# 2     0   461.0
# 3     0   704.0
# 4     0  1040.0

# %%
sam_data.columns=['DATE','PRC','USA','UK','ITL',"FRN",'GER','SPN','IRN','AVG_PRCUS']

# %%
sam_data.head()
# Out:
#          DATE     PRC  USA  UK  ITL  FRN  GER  SPN  IRN  AVG_PRCUS
# 0  2020-01-22   548.0    1   0    0    0    0    0    0      274.5
# 1  2020-01-23   643.0    1   0    0    0    0    0    0      322.0
# 2  2020-01-24   920.0    2   0    0    2    0    0    0      461.0
# 3  2020-01-25  1406.0    2   0    0    3    0    0    0      704.0
# 4  2020-01-26  2075.0    5   0    0    3    0    0    0     1040.0

# %%
sam_data.to_csv('newjupyter')

# %%
import pandas as pd
import numpy as np

# %%
S1={1,2,3}
S1.issubset(S1)
# Out:
# True

# %%
"hello"+'1'
# Out:
# 'hello1'

# %%
"1,1,2,3".split(",")
# Out:
# ['1', '1', '2', '3']

# %%
s1=np.array([1,2,3])
s2=np.array([[1,5],[2,100]])

# %%
s1.extend(s2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-6feb902ea9dc> in <module>
# ----> 1 s1.extend(s2)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'extend'

# %%
i=0
while i<3:
    print(i)
    i+=1
else:
    print(0)
# Out:
# 0
# 1
# 2
# 0

# %%
l=[[1,2,3],[4,5,6]]
for i in range(len(l)):
    for j in range(len(l[i])):
        l[i][j]+=10

# %%
l
# Out:
# [[11, 12, 13], [14, 15, 16]]

# %%
word='aeioubcdfg'
word[:3]#+word[3:]
# Out:
# 'aei'

# %%
gh='3'
type(gh)
int(gh)
# Out:
# 3

# %%
int(gh)
# Out:
# 3

# %%
int(gh)+2
# Out:
# 5

# %%
gh
# Out:
# '3'

# %%
c=1
def do():
    global c
    for i in (1,2,3):
        c+=1
do()
c
# Out:
# 4

# %%
pd.DataFrame([[1,2,3,4],['#','%','7','9']],columns=[10,2,33,44])
# Out:
#   10 2  33 44
# 0  1  2  3  4
# 1  #  %  7  9

# %%
r=lambda q:q*2
s=lambda q:q*3
x=2
x=r(x)
x=s(x)
x=r(x)
x
# Out:
# 24

# %%
x=['ab','cd']
list(map(list,x))
# Out:
# [['a', 'b'], ['c', 'd']]

# %%
gh1=['ab','cd']
map(list,gh1)

# %%
numbers={}
letters={}
comb={}
numbers[1]=56
numbers[3]=7
letters[4]='B'
comb['Numbers']=numbers
comb['Letters']=letters
comb
# Out:
# {'Numbers': {1: 56, 3: 7}, 'Letters': {4: 'B'}}

# %%
a,b,c=1,2,3

# %%
b
# Out:
# 2
