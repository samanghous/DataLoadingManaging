# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Chicago_Crime_Detective.csv')
# Out:
# /home/saman/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year
# ...

# %%
df.Beat.value_counts()
# Out:
# 2512    1619
# 823     1616
# 831     1564
# 2521    1518
# 824     1441
#         ...
# 1225       8
# 1214       7
# 114        5
# 1221       5
# 130        1
# Name: Beat, Length: 300, dtype: int64

# %%
# q1
df[df.columns[0]].median()
# Out:
# 95820.0

# %%
df.loc[95820,:]
# Out:
# Unnamed: 0                     95820
# ID                           4752501
# Date                   5/21/06 12:30
# LocationDescription           STREET
# Arrest                         False
# Domestic                       False
# Beat                             725
# District                           7
# CommunityArea                     67
# Year                            2006
# Name: 95820, dtype: object

# %%
# q2

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year
# ...

# %%
df['samdate']=pd.to_datetime(df.Date)

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year  \
# ...

# %%
df.samdate.dt.month.value_counts()
# Out:
# 10    17086
# 7     16801
# 8     16572
# 12    16426
# 11    16063
# 9     16060
# 1     16047
# 5     16035
# 6     16002
# 3     15758
# 4     15280
# 2     13511
# Name: samdate, dtype: int64

# %%
# q3

# %%
df.samdate.dt.weekday.value_counts()
# Out:
# 4    29284
# 2    27416
# 0    27397
# 3    27319
# 5    27118
# 1    26791
# 6    26316
# Name: samdate, dtype: int64

# %%
# q4

# %%
df[df.Arrest==True]
# Out:
#         Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 5                5  8950793  12/31/12 20:30              STREET    True
# 8                8  8951802  12/31/12 19:00              STREET    True
# 13              13  8950570  12/31/12 16:20         GAS STATION    True
# 47              47  8949895  12/30/12 19:46               ALLEY    True
# 59              59  8949557  12/30/12 15:00              STREET    True
# ...            ...      ...             ...                 ...     ...
# 191600      191600  1311345    1/1/01 18:30              STREET    True
# 191601      191601  1311051    1/1/01 18:00              STREET    True
# 191607      191607  1312461    1/1/01 16:00              STREET    True
# 191628      191628  1310725     1/1/01 3:00              STREET    True
# 191630      191630  1310022     1/1/01 1:50              STREET    True
#
#         Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
df[df.Arrest==True].samdate.dt.month.value_counts()
# Out:
# 1     1435
# 12    1397
# 10    1342
# 8     1329
# 7     1324
# 3     1298
# 11    1256
# 4     1252
# 9     1248
# 2     1238
# 6     1230
# 5     1187
# Name: samdate, dtype: int64

# %%
# q5

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year  \
# ...

# %%
sns.distplot(df.Year)

# %%
sns.countplot(df.Year)

# %%
# q6

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year  \
# ...

# %%
df[df.Arrest==True]
# Out:
#         Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 5                5  8950793  12/31/12 20:30              STREET    True
# 8                8  8951802  12/31/12 19:00              STREET    True
# 13              13  8950570  12/31/12 16:20         GAS STATION    True
# 47              47  8949895  12/30/12 19:46               ALLEY    True
# 59              59  8949557  12/30/12 15:00              STREET    True
# ...            ...      ...             ...                 ...     ...
# 191600      191600  1311345    1/1/01 18:30              STREET    True
# 191601      191601  1311051    1/1/01 18:00              STREET    True
# 191607      191607  1312461    1/1/01 16:00              STREET    True
# 191628      191628  1310725     1/1/01 3:00              STREET    True
# 191630      191630  1310022     1/1/01 1:50              STREET    True
#
#         Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
sns.distplot(df[df.Arrest==True].Year)

# %%
df[df.Arrest==True].Year.value_counts()
# Out:
# 2001    2152
# 2002    2115
# 2003    1798
# 2004    1693
# 2005    1528
# 2006    1302
# 2007    1212
# 2008    1020
# 2009     840
# 2010     701
# 2011     625
# 2012     550
# Name: Year, dtype: int64

# %%
# q7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191641 entries, 0 to 191640
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           191641 non-null  int64
#  1   ID                   191641 non-null  int64
#  2   Date                 191641 non-null  object
#  3   LocationDescription  191641 non-null  object
#  4   Arrest               191641 non-null  bool
#  5   Domestic             191641 non-null  bool
#  6   Beat                 191641 non-null  int64
#  7   District             148589 non-null  object
#  8   CommunityArea        167038 non-null  object
#  9   Year                 191641 non-null  int64
#  10  samdate              191641 non-null  datetime64[ns]
# dtypes: bool(2), datetime64[ns](1), int64(4), object(4)
# memory usage: 13.5+ MB

# %%
df[df.Year==2001]
# Out:
#         Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 170972      170972  1918000  12/31/01 23:00              STREET   False
# 170973      170973  1919009  12/31/01 23:00              STREET   False
# 170974      170974  1917192  12/31/01 22:40              STREET    True
# 170975      170975  1917767  12/31/01 22:15              STREET   False
# 170976      170976  1917193  12/31/01 22:15              STREET   False
# ...            ...      ...             ...                 ...     ...
# 191636      191636  1310068     1/1/01 0:05              STREET   False
# 191637      191637  1313404     1/1/01 0:01              STREET   False
# 191638      191638  1313442     1/1/01 0:01              STREET   False
# 191639      191639  1563324     1/1/01 0:01              STREET   False
# 191640      191640  1310463     1/1/01 0:01              STREET   False
#
#         Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
df1=df[df.Year==2001]
df1[df1.Arrest==True]
# Out:
#         Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 170974      170974  1917192  12/31/01 22:40              STREET    True
# 170987      170987  1938514  12/31/01 19:30               OTHER    True
# 170992      170992  1931084  12/31/01 18:00              STREET    True
# 170995      170995  1917204  12/31/01 17:30              STREET    True
# 171008      171008  1924678   12/31/01 8:00              STREET    True
# ...            ...      ...             ...                 ...     ...
# 191600      191600  1311345    1/1/01 18:30              STREET    True
# 191601      191601  1311051    1/1/01 18:00              STREET    True
# 191607      191607  1312461    1/1/01 16:00              STREET    True
# 191628      191628  1310725     1/1/01 3:00              STREET    True
# 191630      191630  1310022     1/1/01 1:50              STREET    True
#
#         Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
2152/20669
# Out:
# 0.10411727708161982

# %%
# q8

# %%
df[df.Year==2007]
# Out:
#        Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 71838       71838  5993831  12/31/07 23:00              STREET   False
# 71839       71839  5991695  12/31/07 22:30              STREET   False
# 71840       71840  5992891  12/31/07 22:00              STREET   False
# 71841       71841  5992729  12/31/07 22:00              STREET   False
# 71842       71842  5997054  12/31/07 22:00              STREET   False
# ...           ...      ...             ...                 ...     ...
# 86113       86113  5219286     1/1/07 2:00              STREET   False
# 86114       86114  5215650     1/1/07 2:00              STREET   False
# 86115       86115  5229986     1/1/07 2:00              STREET   False
# 86116       86116  5625021     1/1/07 0:01              STREET   False
# 86117       86117  5215059     1/1/07 0:01              STREET   False
#
#        Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
df1=df[df.Year==2007]
df1[df1.Arrest==True]
# Out:
#        Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 71855       71855  6000335  12/31/07 15:00              STREET    True
# 71857       71857  5992596  12/31/07 14:05              STREET    True
# 71860       71860  5998008  12/31/07 13:50              STREET    True
# 71862       71862  5990755  12/31/07 12:00              STREET    True
# 71878       71878  5989181  12/30/07 19:00              STREET    True
# ...           ...      ...             ...                 ...     ...
# 86039       86039  5219070    1/2/07 22:00              STREET    True
# 86074       86074  5215673     1/2/07 0:00              STREET    True
# 86083       86083  5217152    1/1/07 20:00              STREET    True
# 86100       86100  5215246    1/1/07 12:00              STREET    True
# 86111       86111  5215676     1/1/07 2:55              STREET    True
#
#        Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
1212/14280
# Out:
# 0.08487394957983194

# %%
# q9

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year  \
# ...

# %%
df.LocationDescription.value_counts().head(6)
# Out:
# STREET                            156564
# PARKING LOT/GARAGE(NON.RESID.)     14852
# OTHER                               4573
# ALLEY                               2308
# GAS STATION                         2111
# DRIVEWAY - RESIDENTIAL              1675
# Name: LocationDescription, dtype: int64

# %%
# q10

# %%
156564+14852+2308+2111+1675
# Out:
# 177510

# %%
# q11

# %%
df
# Out:
#         Unnamed: 0       ID            Date            LocationDescription  \
# 0                0  8951354  12/31/12 23:15                         STREET
# 1                1  8951141  12/31/12 22:00                         STREET
# 2                2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)
# 3                3  8952223  12/31/12 22:00                         STREET
# 4                4  8951608  12/31/12 21:30                         STREET
# ...            ...      ...             ...                            ...
# 191636      191636  1310068     1/1/01 0:05                         STREET
# 191637      191637  1313404     1/1/01 0:01                         STREET
# 191638      191638  1313442     1/1/01 0:01                         STREET
# 191639      191639  1563324     1/1/01 0:01                         STREET
# 191640      191640  1310463     1/1/01 0:01                         STREET
#
#         Arrest  Domestic  Beat District CommunityArea  Year  \
# ...

# %%
df[df.LocationDescription=='GAS STATION']
# Out:
#         Unnamed: 0       ID            Date LocationDescription  Arrest  \
# 13              13  8950570  12/31/12 16:20         GAS STATION    True
# 106            106  8948353  12/29/12 10:00         GAS STATION   False
# 213            213  8945802  12/27/12 10:00         GAS STATION   False
# 278            278  8943877  12/25/12 10:00         GAS STATION   False
# 290            290  8943595  12/24/12 21:55         GAS STATION   False
# ...            ...      ...             ...                 ...     ...
# 191335      191335  1323645    1/6/01 16:00         GAS STATION   False
# 191350      191350  1319694    1/6/01 11:30         GAS STATION   False
# 191376      191376  1356080    1/5/01 22:00         GAS STATION   False
# 191562      191562  1313797    1/2/01 18:10         GAS STATION   False
# 191583      191583  1312819     1/2/01 8:35         GAS STATION   False
#
#         Domestic  Beat District CommunityArea  Year             samdate
# ...

# %%
df2=df[df.LocationDescription=='GAS STATION']
df2.samdate.dt.weekday.value_counts()
# Out:
# 5    338
# 6    336
# 4    332
# 3    282
# 0    280
# 2    273
# 1    270
# Name: samdate, dtype: int64
